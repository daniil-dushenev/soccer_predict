# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.model_selection import train_test_split
from catboost import Pool, CatBoostClassifier, cv, CatBoostRegressor

# %% [markdown]
# Преобразовали данные

# %%
data = pd.DataFrame()
def create_data(data, seasons=5):
    for i in reversed(range(seasons)):
        df = pd.read_csv(f'{23-i-1}-{23-i}.csv', sep=';')
        df = df.iloc[:-4]
        df = df[['Wk', 'Day', 'Date', 'Time', 'Home', 'Score', 'Away', 'Referee']]
        df['Wk'] = df['Wk'].astype(int)
        df[['Home_score', 'Away_score']] = df['Score'].str.split('–', expand=True)
        df[['Home_score', 'Away_score']] = df[['Home_score', 'Away_score']].astype(int) 
        df['Month'] = df['Date'].apply(lambda x: x[3:5])
        df['Hours'] = df['Time'].apply(lambda x: x[:2]).astype(int)
        df = df.drop(['Score', 'Date', 'Time'], axis=1)
        df['target'] = np.where(df['Home_score'] > df['Away_score'], 0, 
                                np.where(df['Home_score'] < df['Away_score'], 2, 1))
        # 0 - победа хозяев, 1 - ничья, 2 - победа гостей
        df = df.drop(['Home_score', 'Away_score'], axis=1)
        total_df = pd.read_csv(f'{23-i-2}-{23-i-1}_table.csv', sep=';')
        total_df = dict(zip(total_df['Squad'], total_df['Rk']))
        df['Total_last_year_Home'] = df['Home'].apply(lambda x: total_df[x] if x in total_df else None)
        df['Total_last_year_Away'] = df['Away'].apply(lambda x: total_df[x] if x in total_df else None)
        data = pd.concat([data, df], axis=0)
        data = data.dropna()
    return data
df = create_data(data)
df.head()
# Out:
#    Wk  Day          Home  ... target Total_last_year_Home Total_last_year_Away
# 0   1  Sat          Ural  ...      2                 12.0                 14.0
# 2   1  Sat        Rostov  ...      0                 11.0                  9.0
# 3   1  Sun  Arsenal Tula  ...      1                  7.0                  8.0
# 5   1  Sun   Rubin Kazan  ...      0                 10.0                  4.0
# 6   1  Mon           Ufa  ...      1                  6.0                  1.0
#
# [5 rows x 10 columns]

# %%
cat_features = ['Day', 'Home', 'Away', 'Referee', 'Month']
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis=1),
                                                    df['target'], test_size=0.2, shuffle=False)

# %%
train = Pool(data=X_train,
             label=y_train,
             cat_features=cat_features)
test = Pool(data=X_test,
             label=y_test,
             cat_features=cat_features)

# %%
iter = 500
params = {
    "iterations":iter,
    "depth": 3,
    "custom_loss": "Accuracy",
    "learning_rate": 0.1,
    "loss_function": "MultiClass",
    "verbose": False
}
scores = cv(train,
            params,
           fold_count=5)
scores
# Out:
# Training on fold [0/5]
#
# bestTest = 1.063275231
# bestIteration = 19
#
# Training on fold [1/5]
#
# bestTest = 1.017487075
# bestIteration = 172
#
# Training on fold [2/5]
#
# bestTest = 1.046742465
# bestIteration = 57
#
# Training on fold [3/5]
#
# bestTest = 0.9812398041
# bestIteration = 388
#
# Training on fold [4/5]
#
# bestTest = 0.9964749087
# bestIteration = 98
#      iterations  test-MultiClass-mean  ...  train-Accuracy-mean  train-Accuracy-std
# 0             0              1.090966  ...             0.436950            0.016694
# 1             1              1.085192  ...             0.459324            0.010478
# 2             2              1.080761  ...             0.461544            0.027322
# 3             3              1.077003  ...             0.469602            0.017531
# 4             4              1.072553  ...             0.473250            0.014934
# ..          ...                   ...  ...                  ...                 ...
# ...

# %%
plt.figure(figsize=(15, 8))
plt.plot(np.arange(iter), scores['test-Accuracy-mean'].values, label='test scores')
plt.plot(np.arange(iter), scores['train-Accuracy-mean'].values, label='train scores')
plt.legend()
plt.grid(True)
plt.show()

# %%
cb = CatBoostClassifier(iterations=100, depth=3, custom_loss="Accuracy",
                        learning_rate=0.1, loss_function="MultiClass",
                        verbose=False)
cb.fit(train)
y_pred = cb.predict(test)
print("Accuracy: ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.52046783625731

# %%
df_test = pd.read_csv(f'{23}-{24}.csv', sep=';')
df_test = df_test.iloc[:-4]
df_test = df_test[['Wk', 'Day', 'Date', 'Time', 'Home', 'Score', 'Away', 'Referee']]
df_score = df_test
df_test['Wk'] = df_test['Wk'].astype(int)
df_test[['Home_score', 'Away_score']] = df_test['Score'].str.split('–', expand=True)
df_test[['Home_score', 'Away_score']] = df_test[['Home_score', 'Away_score']].astype(int) 
df_test['Month'] = df_test['Date'].apply(lambda x: x[3:5])
df_test['Hours'] = df_test['Time'].apply(lambda x: x[:2]).astype(int)

df_test = df_test.drop(['Score', 'Date', 'Time'], axis=1)
df_test = df_test.drop(['Home_score', 'Away_score'], axis=1)
total_df = pd.read_csv(f'{22}-{23}_table.csv', sep=';')
total_df = dict(zip(total_df['Squad'], total_df['Rk']))
df_test['Total_last_year_Home'] = df_test['Home'].apply(lambda x: total_df[x] if x in total_df else None)
df_test['Total_last_year_Away'] = df_test['Away'].apply(lambda x: total_df[x] if x in total_df else None)
df_test = df_test.dropna()
df_test
# Out:
#     Wk  Day             Home  ... Hours Total_last_year_Home Total_last_year_Away
# 0    1  Fri      Dynamo Mosc  ...    19                  9.0                  6.0
# 1    1  Sat             Ural  ...    15                 11.0                  2.0
# 2    1  Sat  Nizhny Novgorod  ...    15                 13.0                  1.0
# 4    1  Sat    Akhmat Grozny  ...    20                  5.0                 12.0
# 5    1  Sun   Spartak Moscow  ...    17                  3.0                  7.0
# 6    1  Sun           Rostov  ...    20                  4.0                 14.0
# 8    2  Sat           Samara  ...    16                 12.0                  9.0
# 9    2  Sat             Ural  ...    19                 11.0                 13.0
# 10   2  Sat           Rostov  ...    20                  4.0                  1.0
# 12   2  Sun   Fakel Voronezh  ...    17                 14.0                  8.0
# ...

# %%
for i in range(len(df_test)):
    match = df_test.iloc[i]
    result = {0: 'П1', 1: 'Н', 2: 'П2'}
    print(f"{match['Home']} - {match['Away']}", result[cb.predict(match)[0]], df_score.\
                         loc[(match['Home']==df_score['Home']) & (match['Away']==df_score['Away'])]['Score'].iloc[0],
                         cb.predict_proba(match))
# Out:
# Dynamo Mosc - Krasnodar П1 1–3 [0.41098287 0.24356757 0.34544955]
# Ural - CSKA Moscow П2 2–1 [0.22687972 0.26039981 0.51272047]
# Nizhny Novgorod - Zenit П2 0–2 [0.1269626  0.21052886 0.66250853]
# Akhmat Grozny - Samara П1 1–2 [0.56701126 0.19311651 0.23987223]
# Spartak Moscow - Orenburg П1 3–2 [0.5556511  0.18812867 0.25622024]
# Rostov - Fakel Voronezh П1 2–1 [0.67440028 0.17421214 0.15138758]
# Samara - Dynamo Mosc П2 3–3 [0.17061386 0.30877206 0.52061407]
# Ural - Nizhny Novgorod П1 0–0 [0.50803568 0.23568988 0.25627444]
# Rostov - Zenit П2 1–1 [0.31326995 0.20567006 0.48105999]
# Fakel Voronezh - Loko Moscow П2 1–4 [0.21241596 0.26864954 0.5189345 ]
# Akhmat Grozny - CSKA Moscow П2 2–3 [0.38252732 0.2308447  0.38662798]
# Krasnodar - Sochi П1 2–0 [0.54059941 0.21522226 0.24417833]
# Krasnodar - Nizhny Novgorod П1 1–0 [0.64691517 0.20622821 0.14685662]
# Samara - Rostov П2 5–1 [0.14985305 0.2816011  0.56854584]
# Orenburg - Ural П2 0–2 [0.23672734 0.28661485 0.47665781]
# ...

# %%
feature_importance = cb.get_feature_importance()
feature_names = X_train.columns 

plt.figure(figsize=(10, 6))
plt.barh(feature_names, feature_importance)
plt.xlabel('Feature Importance')
plt.ylabel('Feature Name')
plt.title('Feature Importance')
plt.show()

# %%
df_zenit = create_data(pd.DataFrame())
df_zenit = df_zenit.loc[(df_zenit['Home'] == 'Zenit') | (df_zenit['Away'] == 'Zenit')]
df_zenit['Zenit_is_win'] = np.where(df_zenit['Home'] == 'Zenit', df_zenit['target'] == 0, df_zenit['target'] == 2)
plt.figure(figsize=(8, 6))
sns.histplot(data=df_zenit, y='Referee', hue='Zenit_is_win', multiple='dodge', shrink=0.8)
plt.xlabel('Referees')
plt.ylabel('Count')
plt.title('Зависимость побед Зенита от судей')
plt.show()

# %% [markdown]
# Преобразуем данные под регрессию

# %%
df['target'] = df['target'].replace({1: 0.5, 2: 1})

# %%
cat_features = ['Day', 'Home', 'Away', 'Referee', 'Month']
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis=1),
                                                    df['target'], test_size=0.2, shuffle=False)
train = Pool(data=X_train,
             label=y_train,
             cat_features=cat_features)
test = Pool(data=X_test,
             label=y_test,
             cat_features=cat_features)
df
# Out:
#      Wk  Day  ... Total_last_year_Home Total_last_year_Away
# 0     1  Sat  ...                 12.0                 14.0
# 2     1  Sat  ...                 11.0                  9.0
# 3     1  Sun  ...                  7.0                  8.0
# 5     1  Sun  ...                 10.0                  4.0
# 6     1  Mon  ...                  6.0                  1.0
# ..   ..  ...  ...                  ...                  ...
# 234  30  Sat  ...                 11.0                 13.0
# 235  30  Sat  ...                  7.0                  4.0
# 236  30  Sat  ...                  5.0                  9.0
# 237  30  Sat  ...                  8.0                 10.0
# 239  30  Sat  ...                 12.0                  2.0
#
# [853 rows x 10 columns]

# %%
cbr = CatBoostRegressor(iterations=100, depth=3,
                        learning_rate=0.1, loss_function="RMSE",
                        verbose=False)
cbr.fit(train)
y_pred = cbr.predict(test)
print("Accuracy: ", mean_squared_error(y_test, y_pred, squared=False))
# Out:
# Accuracy:  0.4058611909219813

# %%
for i in range(len(df_test)):
    match = df_test.iloc[i]
    result = 'П1'
    if cbr.predict(match) >= 0.6: 
        result = 'П2'
    elif 0.4 < cbr.predict(match) < 0.6: 
        result = 'Н'
    print(f"{match['Home']} - {match['Away']}", df_score.\
                         loc[(match['Home']==df_score['Home']) & (match['Away']==df_score['Away'])]['Score'].iloc[0],
                         result, cbr.predict(match))
# Out:
# Dynamo Mosc - Krasnodar 1–3 Н 0.5018273702115845
# Ural - CSKA Moscow 2–1 П2 0.6311212023095494
# Nizhny Novgorod - Zenit 0–2 П2 0.72646620086027
# Akhmat Grozny - Samara 1–2 П1 0.353985162275968
# Spartak Moscow - Orenburg 3–2 П1 0.3941394851975732
# Rostov - Fakel Voronezh 2–1 П1 0.30749069254668604
# Samara - Dynamo Mosc 3–3 П2 0.7300269309483118
# Ural - Nizhny Novgorod 0–0 Н 0.4358142234238074
# Rostov - Zenit 1–1 Н 0.5665272697631591
# Fakel Voronezh - Loko Moscow 1–4 П2 0.6765977433197453
# Akhmat Grozny - CSKA Moscow 2–3 Н 0.5374315782193968
# Krasnodar - Sochi 2–0 Н 0.47830684586601824
# Krasnodar - Nizhny Novgorod 1–0 П1 0.2705700625304398
# Samara - Rostov 5–1 П2 0.6833601151109943
# Orenburg - Ural 0–2 Н 0.577958727892327
# CSKA Moscow - Loko Moscow 4–1 П1 0.3567373625133559
