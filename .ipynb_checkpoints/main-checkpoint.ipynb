# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from catboost import Pool, CatBoostClassifier, cv

# %% [markdown]
# Преобразовали данные

# %%
df1 = pd.read_csv('21-22.csv', sep=';')
def create_df(df):
    df = df.iloc[:-4]
    df = df[['Wk', 'Day', 'Date', 'Time', 'Home', 'Score', 'Away', 'Referee']]
    df['Wk'] = df['Wk'].astype(int)
    df[['Home_score', 'Away_score']] = df['Score'].str.split('–', expand=True)
    df[['Home_score', 'Away_score']] = df[['Home_score', 'Away_score']].astype(int) 
    df['Month'] = df['Date'].apply(lambda x: x[3:5])
    df['Hours'] = df['Time'].apply(lambda x: x[:2]).astype(int)
    df = df.drop(['Score', 'Date', 'Time'], axis=1)
    df['target'] = np.where(df['Home_score'] > df['Away_score'], 1, 
                            np.where(df['Home_score'] < df['Away_score'], 2, 0))
    # 1 - победа хозяев, 0 - ничья, 2 - победа гостей
    df = df.drop(['Home_score', 'Away_score'], axis=1)
    return df
df1 = create_df(df1)
df1
# Out:
#      Wk  Day          Home            Away               Referee Month  Hours  \
# 0     1  Fri        Rostov     Dynamo Mosc     Vladimir Moskalev    07     20
# 1     1  Sat     FC Khimki           Zenit       Evgeny Kukulyak    07     17
# 2     1  Sat   Rubin Kazan  Spartak Moscow  Vladislav Bezborodov    07     20
# 3     1  Sat   Loko Moscow    Arsenal Tula            Igor Panin    07     20
# 4     1  Sun          Ural       Krasnodar     Vasiliy Kazartsev    07     19
# ..   ..  ...           ...             ...                   ...   ...    ...
# 235  30  Sat     FC Khimki  Spartak Moscow        Sergey Karasev    05     17
# 236  30  Sat   CSKA Moscow          Rostov        Yan Bobrovskiy    05     17
# 237  30  Sat   Dynamo Mosc           Sochi     Vladimir Moskalev    05     17
# 238  30  Sat     Krasnodar   Akhmat Grozny     Pavel Shadykhanov    05     17
# 239  30  Sat  Arsenal Tula            Ural         Pavel Kukuyan    05     21
#
#      target
# 0         2
# 1         2
# 2         1
# 3         1
# 4         2
# ..      ...
# 235       1
# 236       1
# 237       2
# 238       0
# 239       2
#
# [240 rows x 8 columns]

# %%
Total_20_21 = {'Rostov': 9, 'FC Khimki': 8, 'Rubin Kazan': 4, 'Loko Moscow': 3, 'Ural': 12,
       'Samara': None, 'CSKA Moscow': 6, 'Nizhny Novgorod': None, 'Arsenal Tula': 14, 'Ufa':13,
       'Krasnodar':10, 'Akhmat Grozny':11, 'Zenit':1, 'Spartak Moscow':2,
       'Dynamo Mosc':7, 'Sochi':5}
df1['Total_last_year_Home'] = df1['Home'].apply(lambda x: Total_20_21[x])
df1['Total_last_year_Away'] = df1['Away'].apply(lambda x: Total_20_21[x])
df1
# Out:
#      Wk  Day          Home            Away               Referee Month  Hours  \
# 0     1  Fri        Rostov     Dynamo Mosc     Vladimir Moskalev    07     20
# 1     1  Sat     FC Khimki           Zenit       Evgeny Kukulyak    07     17
# 2     1  Sat   Rubin Kazan  Spartak Moscow  Vladislav Bezborodov    07     20
# 3     1  Sat   Loko Moscow    Arsenal Tula            Igor Panin    07     20
# 4     1  Sun          Ural       Krasnodar     Vasiliy Kazartsev    07     19
# ..   ..  ...           ...             ...                   ...   ...    ...
# 235  30  Sat     FC Khimki  Spartak Moscow        Sergey Karasev    05     17
# 236  30  Sat   CSKA Moscow          Rostov        Yan Bobrovskiy    05     17
# 237  30  Sat   Dynamo Mosc           Sochi     Vladimir Moskalev    05     17
# 238  30  Sat     Krasnodar   Akhmat Grozny     Pavel Shadykhanov    05     17
# 239  30  Sat  Arsenal Tula            Ural         Pavel Kukuyan    05     21
#
#      target  Total_last_year_Home  Total_last_year_Away
# 0         2                   9.0                   7.0
# 1         2                   8.0                   1.0
# 2         1                   4.0                   2.0
# 3         1                   3.0                  14.0
# 4         2                  12.0                  10.0
# ..      ...                   ...                   ...
# 235       1                   8.0                   2.0
# 236       1                   6.0                   9.0
# 237       2                   7.0                   5.0
# 238       0                  10.0                  11.0
# 239       2                  14.0                  12.0
#
# [240 rows x 10 columns]

# %%
df2 = pd.read_csv('22-23.csv', sep=';')
df2 = create_df(df2)
Total_21_22 = {'FC Khimki':13, 'CSKA Moscow':5, 'Orenburg':None, 'Akhmat Grozny':7,
       'Torpedo Moscow':None, 'Loko Moscow':6, 'Dynamo Mosc':3, 'Krasnodar':4,
       'Zenit':1, 'Ural':12, 'Fakel Voronezh':None, 'Sochi':2, 'Nizhny Novgorod':11,
       'Spartak Moscow':10, 'Samara':8, 'Rostov':9}
df2['Total_last_year_Home'] = df2['Home'].apply(lambda x: Total_21_22[x])
df2['Total_last_year_Away'] = df2['Away'].apply(lambda x: Total_21_22[x])
df2
# Out:
#      Wk  Day            Home            Away               Referee Month  \
# 0     1  Fri       FC Khimki           Zenit       Evgeny Kukulyak    07
# 1     1  Sat     CSKA Moscow            Ural        Vitaly Meshkov    07
# 2     1  Sat        Orenburg          Samara     Pavel Shadykhanov    07
# 3     1  Sat   Akhmat Grozny  Spartak Moscow  Vladislav Bezborodov    07
# 4     1  Sun  Torpedo Moscow           Sochi         Sergey Ivanov    07
# ..   ..  ...             ...             ...                   ...   ...
# 235  30  Sat   Akhmat Grozny       Krasnodar        Rafael Shafeev    06
# 236  30  Sat     CSKA Moscow          Rostov         Pavel Kukuyan    06
# 237  30  Sat          Samara  Spartak Moscow        Aleksey Amelin    06
# 238  30  Sat        Orenburg     Dynamo Mosc         Sergey Ivanov    06
# 239  30  Sat            Ural           Sochi     Vladimir Moskalev    06
#
#      Hours  target  Total_last_year_Home  Total_last_year_Away
# 0       20       0                  13.0                   1.0
# 1       15       1                   5.0                  12.0
# 2       19       2                   NaN                   8.0
# 3       20       0                   7.0                  10.0
# 4       15       2                   NaN                   2.0
# ..     ...     ...                   ...                   ...
# 235     17       0                   7.0                   4.0
# 236     17       1                   5.0                   9.0
# 237     18       1                   8.0                  10.0
# 238     19       1                   NaN                   3.0
# 239     19       1                  12.0                   2.0
#
# [240 rows x 10 columns]

# %%
df = pd.concat([df1, df2], axis=0)
df
# Out:
#      Wk  Day           Home            Away               Referee Month  \
# 0     1  Fri         Rostov     Dynamo Mosc     Vladimir Moskalev    07
# 1     1  Sat      FC Khimki           Zenit       Evgeny Kukulyak    07
# 2     1  Sat    Rubin Kazan  Spartak Moscow  Vladislav Bezborodov    07
# 3     1  Sat    Loko Moscow    Arsenal Tula            Igor Panin    07
# 4     1  Sun           Ural       Krasnodar     Vasiliy Kazartsev    07
# ..   ..  ...            ...             ...                   ...   ...
# 235  30  Sat  Akhmat Grozny       Krasnodar        Rafael Shafeev    06
# 236  30  Sat    CSKA Moscow          Rostov         Pavel Kukuyan    06
# 237  30  Sat         Samara  Spartak Moscow        Aleksey Amelin    06
# 238  30  Sat       Orenburg     Dynamo Mosc         Sergey Ivanov    06
# 239  30  Sat           Ural           Sochi     Vladimir Moskalev    06
#
#      Hours  target  Total_last_year_Home  Total_last_year_Away
# 0       20       2                   9.0                   7.0
# 1       17       2                   8.0                   1.0
# 2       20       1                   4.0                   2.0
# 3       20       1                   3.0                  14.0
# 4       19       2                  12.0                  10.0
# ..     ...     ...                   ...                   ...
# 235     17       0                   7.0                   4.0
# 236     17       1                   5.0                   9.0
# 237     18       1                   8.0                  10.0
# 238     19       1                   NaN                   3.0
# 239     19       1                  12.0                   2.0
#
# [480 rows x 10 columns]

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338 entries, 0 to 239
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Wk                    338 non-null    int64
#  1   Day                   338 non-null    object
#  2   Home                  338 non-null    object
#  3   Away                  338 non-null    object
#  4   Referee               338 non-null    object
#  5   Month                 338 non-null    object
#  6   Hours                 338 non-null    int64
#  7   target                338 non-null    int64
#  8   Total_last_year_Home  338 non-null    float64
#  9   Total_last_year_Away  338 non-null    float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 29.0+ KB

# %%
cat_features = ['Day', 'Home', 'Away', 'Referee', 'Month']
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis=1),
                                                    df['target'], test_size=0.2)

# %%
train = Pool(data=X_train,
             label=y_train,
             cat_features=cat_features)
test = Pool(data=X_test,
             label=y_test,
             cat_features=cat_features)

# %%
iter = 500
params = {
    "iterations":iter,
    "depth": 3,
    "custom_loss": "Accuracy",
    "learning_rate": 0.05,
    "loss_function": "MultiClass",
    "verbose": False
}
scores = cv(train,
            params,
           fold_count=5)
scores
# Out:
# Training on fold [0/5]
#
# bestTest = 0.9328059629
# bestIteration = 493
#
# Training on fold [1/5]
#
# bestTest = 1.034252882
# bestIteration = 116
#
# Training on fold [2/5]
#
# bestTest = 1.050427212
# bestIteration = 134
#
# Training on fold [3/5]
#
# bestTest = 1.013731375
# bestIteration = 124
#
# Training on fold [4/5]
#
# bestTest = 1.043436599
# bestIteration = 68
#      iterations  test-MultiClass-mean  test-MultiClass-std  \
# 0             0              1.094317             0.001550
# 1             1              1.090982             0.001607
# 2             2              1.087518             0.001069
# 3             3              1.084564             0.001336
# 4             4              1.081941             0.002485
# ..          ...                   ...                  ...
# 495         495              1.061100             0.072432
# 496         496              1.061206             0.072210
# 497         497              1.061293             0.071817
# 498         498              1.060970             0.071469
# 499         499              1.060815             0.071339
#
#      train-MultiClass-mean  train-MultiClass-std  test-Accuracy-mean  \
# 0                 1.093100              0.001318            0.429691
# 1                 1.088239              0.001418            0.429341
# 2                 1.083365              0.002632            0.455689
# 3                 1.078942              0.003470            0.448002
# 4                 1.074499              0.004170            0.437098
# ..                     ...                   ...                 ...
# 495               0.545212              0.009313            0.480869
# 496               0.544764              0.009161            0.480869
# 497               0.544442              0.009134            0.480869
# 498               0.544125              0.009230            0.484505
# 499               0.543555              0.009484            0.488209
#
#      test-Accuracy-std  train-Accuracy-mean  train-Accuracy-std
# 0             0.016620             0.462971            0.019551
# 1             0.042842             0.474996            0.010286
# 2             0.030227             0.490694            0.026015
# 3             0.042051             0.491624            0.025839
# 4             0.053679             0.498997            0.043478
# ..                 ...                  ...                 ...
# 495           0.077954             0.901847            0.007677
# 496           0.077954             0.902773            0.005765
# 497           0.077954             0.903699            0.006126
# 498           0.085972             0.903699            0.006126
# 499           0.084195             0.902773            0.008086
#
# [500 rows x 9 columns]

# %%
plt.figure(figsize=(15, 8))
plt.plot(np.arange(iter), scores['test-Accuracy-mean'].values, label='test scores')
plt.plot(np.arange(iter), scores['train-Accuracy-mean'].values, label='train scores')
plt.legend()
plt.grid(True)
plt.show()

# %%
cb = CatBoostClassifier(iterations=70, depth=3, custom_loss="Accuracy",
                        learning_rate=0.05, loss_function="MultiClass",
                        verbose=False)
cb.fit(train)

# %%
data = pd.read_csv('23-24.csv', sep=';')
data = create_df(data)
m1 = data.iloc[6]       # Берем матч Ростов-Факел
m1['Total_last_year_Home'] = 4
m1['Total_last_year_Away'] = 14
m1
# Out:
# Wk                                      1
# Day                                   Sun
# Home                               Rostov
# Away                       Fakel Voronezh
# Referee                 Pavel Shadykhanov
# Month                                  07
# Hours                                  20
# target                                  1
# Total_last_year_Home                    4
# Total_last_year_Away                   14
# Name: 6, dtype: object

# %%
print(cb.predict(m1)[0], cb.predict_proba(m1)) # Он предсказал победу Ростова в матче Ростов-Факел
                                  # Реальный счет 2-1 в пользу Ростова
# Out:
# 1 [0.2005312  0.53524789 0.26422091]

# %%
data
# Out:
#     Wk  Day             Home                    Away               Referee  \
# 0    1  Fri      Dynamo Mosc               Krasnodar       Kirill Levnikov
# 1    1  Sat             Ural             CSKA Moscow        Aleksey Amelin
# 2    1  Sat  Nizhny Novgorod                   Zenit         Sergey Ivanov
# 3    1  Sat      Loko Moscow             Rubin Kazan  Vladislav Bezborodov
# 4    1  Sat    Akhmat Grozny                  Samara        Sergey Karasev
# 5    1  Sun   Spartak Moscow                Orenburg      Artem Chistyakov
# 6    1  Sun           Rostov          Fakel Voronezh     Pavel Shadykhanov
# 7    1  Sun            Sochi  FC Baltika Kaliningrad        Rafael Shafeev
# 8    2  Sat           Samara             Dynamo Mosc        Artem Lyubimov
# 9    2  Sat             Ural         Nizhny Novgorod      Artem Chistyakov
# 10   2  Sat           Rostov                   Zenit       Evgeny Kukulyak
# 11   2  Sun      Rubin Kazan                Orenburg        Vitaly Meshkov
# 12   2  Sun   Fakel Voronezh             Loko Moscow     Vasiliy Kazartsev
# 13   2  Sun    Akhmat Grozny             CSKA Moscow  Vladislav Bezborodov
# 14   2  Sun        Krasnodar                   Sochi     Vladimir Moskalev
# 15   2  Mon   Spartak Moscow  FC Baltika Kaliningrad         Pavel Kukuyan
# 16   3  Fri        Krasnodar         Nizhny Novgorod        Artem Lyubimov
# 17   3  Sat           Samara                  Rostov        Sergey Karasev
# 18   3  Sat      Rubin Kazan          Spartak Moscow       Evgeny Kukulyak
# 19   3  Sat         Orenburg                    Ural        Rafael Shafeev
# 20   3  Sat      CSKA Moscow             Loko Moscow       Kirill Levnikov
#
#    Month  Hours  target
# 0     07     19       2
# 1     07     15       1
# 2     07     15       2
# 3     07     17       0
# 4     07     20       2
# 5     07     17       1
# 6     07     20       1
# 7     07     21       1
# 8     07     16       0
# 9     07     19       0
# 10    07     20       0
# 11    07     15       0
# 12    07     17       2
# 13    07     20       2
# 14    07     20       1
# 15    07     19       1
# 16    08     20       1
# 17    08     16       1
# 18    08     17       2
# 19    08     19       2
# 20    08     20       1

# %%
m2 = data.iloc[10]   # Ростов-Зенит
m2['Total_last_year_Home'] = 4
m2['Total_last_year_Away'] = 1
m2
# Out:
# Wk                                    2
# Day                                 Sat
# Home                             Rostov
# Away                              Zenit
# Referee                 Evgeny Kukulyak
# Month                                07
# Hours                                20
# target                                0
# Total_last_year_Home                  4
# Total_last_year_Away                  1
# Name: 10, dtype: object

# %%
print(cb.predict(m2)[0], cb.predict_proba(m2))  # Он предсказал победу Ростова, реальный счет 1-1
# Out:
# 1 [0.25801897 0.44134892 0.30063212]

# %%
m3 = data.iloc[20]    # ЦСКА - Локомотив
m3['Total_last_year_Home'] = 2
m3['Total_last_year_Away'] = 8
m3
# Out:
# Wk                                    3
# Day                                 Sat
# Home                        CSKA Moscow
# Away                        Loko Moscow
# Referee                 Kirill Levnikov
# Month                                08
# Hours                                20
# target                                1
# Total_last_year_Home                  2
# Total_last_year_Away                  8
# Name: 20, dtype: object

# %%
print(cb.predict(m3)[0], cb.predict_proba(m3))  # С отрывом предсказал победу ЦСКА,
                                                # реальный счет 4-1 в пользу ЦСКА
# Out:
# 1 [0.22387223 0.48156343 0.29456434]

# %%
cb.get_feature_importance(train)
# Out:
# array([ 1.35789745,  5.81200137, 11.10179669, 14.31548072,  6.03707562,
#         7.19992206,  7.8094671 , 21.54016512, 24.82619386])

# %%
X_train.columns
# Out:
# Index(['Wk', 'Day', 'Home', 'Away', 'Referee', 'Month', 'Hours',
#        'Total_last_year_Home', 'Total_last_year_Away'],
#       dtype='object')
