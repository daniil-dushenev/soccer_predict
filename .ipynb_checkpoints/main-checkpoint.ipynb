# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from catboost import Pool, CatBoostClassifier, cv

# %% [markdown]
# Преобразовали данные

# %%
data = pd.DataFrame()
def create_data(data, seasons=5):
    for i in range(seasons):
        df = pd.read_csv(f'{23-i-1}-{23-i}.csv', sep=';')
        df = df.iloc[:-4]
        df = df[['Wk', 'Day', 'Date', 'Time', 'Home', 'Score', 'Away', 'Referee']]
        df['Wk'] = df['Wk'].astype(int)
        df[['Home_score', 'Away_score']] = df['Score'].str.split('–', expand=True)
        df[['Home_score', 'Away_score']] = df[['Home_score', 'Away_score']].astype(int) 
        df['Month'] = df['Date'].apply(lambda x: x[3:5])
        df['Hours'] = df['Time'].apply(lambda x: x[:2]).astype(int)
        df = df.drop(['Score', 'Date', 'Time'], axis=1)
        df['target'] = np.where(df['Home_score'] > df['Away_score'], 0, 
                                np.where(df['Home_score'] < df['Away_score'], 2, 1))
        # 0 - победа хозяев, 1 - ничья, 2 - победа гостей
        df = df.drop(['Home_score', 'Away_score'], axis=1)
        total_df = pd.read_csv(f'{23-i-2}-{23-i-1}_table.csv', sep=';')
        total_df = dict(zip(total_df['Squad'], total_df['Rk']))
        df['Total_last_year_Home'] = df['Home'].apply(lambda x: total_df[x] if x in total_df else None)
        df['Total_last_year_Away'] = df['Away'].apply(lambda x: total_df[x] if x in total_df else None)
        data = pd.concat([data, df], axis=0)
        data = data.dropna()
    return data
df = create_data(data)

# %%
cat_features = ['Day', 'Home', 'Away', 'Referee', 'Month']
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis=1),
                                                    df['target'], test_size=0.2)

# %%
train = Pool(data=X_train,
             label=y_train,
             cat_features=cat_features)
test = Pool(data=X_test,
             label=y_test,
             cat_features=cat_features)

# %%
iter = 500
params = {
    "iterations":iter,
    "depth": 3,
    "custom_loss": "Accuracy",
    "learning_rate": 0.1,
    "loss_function": "MultiClass",
    "verbose": False
}
scores = cv(train,
            params,
           fold_count=5)
scores
# Out:
# Training on fold [0/5]
#
# bestTest = 1.046333691
# bestIteration = 158
#
# Training on fold [1/5]
#
# bestTest = 1.047564735
# bestIteration = 52
#
# Training on fold [2/5]
#
# bestTest = 1.016217895
# bestIteration = 102
#
# Training on fold [3/5]
#
# bestTest = 1.053605991
# bestIteration = 60
#
# Training on fold [4/5]
#
# bestTest = 0.9968545089
# bestIteration = 95
#      iterations  test-MultiClass-mean  test-MultiClass-std  \
# 0             0              1.092378             0.002667
# 1             1              1.087521             0.003420
# 2             2              1.082766             0.003838
# 3             3              1.080359             0.002508
# 4             4              1.075502             0.003736
# ..          ...                   ...                  ...
# 495         495              1.084406             0.039413
# 496         496              1.084514             0.040175
# 497         497              1.084695             0.040222
# 498         498              1.084903             0.040220
# 499         499              1.084763             0.039869
#
#      train-MultiClass-mean  train-MultiClass-std  test-Accuracy-mean  \
# 0                 1.091075              0.002164            0.445832
# 1                 1.083019              0.002338            0.434132
# 2                 1.077338              0.002135            0.438534
# 3                 1.072811              0.003301            0.459143
# 4                 1.066239              0.003614            0.451747
# ..                     ...                   ...                 ...
# 495               0.624918              0.007029            0.466230
# 496               0.624366              0.006891            0.467700
# 497               0.623841              0.006964            0.466230
# 498               0.623373              0.007077            0.464770
# 499               0.622977              0.006982            0.466241
#
#      test-Accuracy-std  train-Accuracy-mean  train-Accuracy-std
# 0             0.032792             0.450500            0.017518
# 1             0.025274             0.468470            0.013748
# 2             0.029281             0.467016            0.012077
# 3             0.041627             0.479474            0.013073
# 4             0.028226             0.483160            0.015950
# ..                 ...                  ...                 ...
# 495           0.039044             0.836507            0.004501
# 496           0.040403             0.837975            0.005323
# 497           0.039044             0.838710            0.004446
# 498           0.040804             0.838709            0.004310
# 499           0.045490             0.838708            0.005248
#
# [500 rows x 9 columns]

# %%
plt.figure(figsize=(15, 8))
plt.plot(np.arange(iter), scores['test-Accuracy-mean'].values, label='test scores')
plt.plot(np.arange(iter), scores['train-Accuracy-mean'].values, label='train scores')
plt.legend()
plt.grid(True)
plt.show()

# %%
cb = CatBoostClassifier(iterations=100, depth=3, custom_loss="Accuracy",
                        learning_rate=0.1, loss_function="MultiClass",
                        verbose=False)
cb.fit(train)
y_pred = cb.predict(test)
print("Accuracy: ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.5321637426900585

# %%
df_test = pd.read_csv(f'{23}-{24}.csv', sep=';')
df_test = df_test.iloc[:-4]
df_test = df_test[['Wk', 'Day', 'Date', 'Time', 'Home', 'Score', 'Away', 'Referee']]
df_score = df_test
df_test['Wk'] = df_test['Wk'].astype(int)
df_test[['Home_score', 'Away_score']] = df_test['Score'].str.split('–', expand=True)
df_test[['Home_score', 'Away_score']] = df_test[['Home_score', 'Away_score']].astype(int) 
df_test['Month'] = df_test['Date'].apply(lambda x: x[3:5])
df_test['Hours'] = df_test['Time'].apply(lambda x: x[:2]).astype(int)

df_test = df_test.drop(['Score', 'Date', 'Time'], axis=1)
df_test = df_test.drop(['Home_score', 'Away_score'], axis=1)
total_df = pd.read_csv(f'{22}-{23}_table.csv', sep=';')
total_df = dict(zip(total_df['Squad'], total_df['Rk']))
df_test['Total_last_year_Home'] = df_test['Home'].apply(lambda x: total_df[x] if x in total_df else None)
df_test['Total_last_year_Away'] = df_test['Away'].apply(lambda x: total_df[x] if x in total_df else None)
df_test = df_test.dropna()
df_test
# Out:
#     Wk  Day             Home             Away               Referee Month  \
# 0    1  Fri      Dynamo Mosc        Krasnodar       Kirill Levnikov    07
# 1    1  Sat             Ural      CSKA Moscow        Aleksey Amelin    07
# 2    1  Sat  Nizhny Novgorod            Zenit         Sergey Ivanov    07
# 4    1  Sat    Akhmat Grozny           Samara        Sergey Karasev    07
# 5    1  Sun   Spartak Moscow         Orenburg      Artem Chistyakov    07
# 6    1  Sun           Rostov   Fakel Voronezh     Pavel Shadykhanov    07
# 8    2  Sat           Samara      Dynamo Mosc        Artem Lyubimov    07
# 9    2  Sat             Ural  Nizhny Novgorod      Artem Chistyakov    07
# 10   2  Sat           Rostov            Zenit       Evgeny Kukulyak    07
# 12   2  Sun   Fakel Voronezh      Loko Moscow     Vasiliy Kazartsev    07
# 13   2  Sun    Akhmat Grozny      CSKA Moscow  Vladislav Bezborodov    07
# 14   2  Sun        Krasnodar            Sochi     Vladimir Moskalev    07
# 16   3  Fri        Krasnodar  Nizhny Novgorod        Artem Lyubimov    08
# 17   3  Sat           Samara           Rostov        Sergey Karasev    08
# 19   3  Sat         Orenburg             Ural        Rafael Shafeev    08
# 20   3  Sat      CSKA Moscow      Loko Moscow       Kirill Levnikov    08
#
#     Hours  Total_last_year_Home  Total_last_year_Away
# 0      19                   9.0                   6.0
# 1      15                  11.0                   2.0
# 2      15                  13.0                   1.0
# 4      20                   5.0                  12.0
# 5      17                   3.0                   7.0
# 6      20                   4.0                  14.0
# 8      16                  12.0                   9.0
# 9      19                  11.0                  13.0
# 10     20                   4.0                   1.0
# 12     17                  14.0                   8.0
# 13     20                   5.0                   2.0
# 14     20                   6.0                  10.0
# 16     20                   6.0                  13.0
# 17     16                  12.0                   4.0
# 19     19                   7.0                  11.0
# 20     20                   2.0                   8.0

# %%
for i in range(len(df_test)):
    match = df_test.iloc[i]
    result = {0: 'П1', 1: 'Н', 2: 'П2'}
    print(f"{match['Home']} - {match['Away']}", result[cb.predict(match)[0]], df_score.\
                         loc[(match['Home']==df_score['Home']) & (match['Away']==df_score['Away'])]['Score'].iloc[0],
                         cb.predict_proba(match))
# Out:
# Dynamo Mosc - Krasnodar П1 1–3 [0.37170281 0.31483    0.31346718]
# Ural - CSKA Moscow П2 2–1 [0.22124964 0.29667539 0.48207497]
# Nizhny Novgorod - Zenit П2 0–2 [0.14632214 0.25827287 0.59540499]
# Akhmat Grozny - Samara П1 1–2 [0.58878043 0.204712   0.20650757]
# Spartak Moscow - Orenburg П1 3–2 [0.48177483 0.22861841 0.28960676]
# Rostov - Fakel Voronezh П1 2–1 [0.76879749 0.1225152  0.10868731]
# Samara - Dynamo Mosc П2 3–3 [0.19462518 0.30645671 0.49891812]
# Ural - Nizhny Novgorod П1 0–0 [0.56516397 0.22332664 0.21150939]
# Rostov - Zenit П2 1–1 [0.33178192 0.27151544 0.39670264]
# Fakel Voronezh - Loko Moscow П2 1–4 [0.14808829 0.21372123 0.63819048]
# Akhmat Grozny - CSKA Moscow П1 2–3 [0.38401838 0.28635855 0.32962307]
# Krasnodar - Sochi П1 2–0 [0.50494827 0.23365765 0.26139409]
# Krasnodar - Nizhny Novgorod П1 1–0 [0.7316376  0.12979033 0.13857206]
# Samara - Rostov П2 5–1 [0.20663972 0.30820636 0.48515391]
# Orenburg - Ural П2 0–2 [0.33231048 0.2683385  0.39935102]
# CSKA Moscow - Loko Moscow П1 4–1 [0.51092511 0.24275576 0.24631912]

# %%
feature_importance = cb.get_feature_importance()
feature_names = X_train.columns 

plt.figure(figsize=(10, 6))
plt.barh(feature_names, feature_importance)
plt.xlabel('Feature Importance')
plt.ylabel('Feature Name')
plt.title('Feature Importance')
plt.show()

# %%
df_zenit = create_data(pd.DataFrame())
df_zenit = df_zenit.loc[(df_zenit['Home'] == 'Zenit') | (df_zenit['Away'] == 'Zenit')]
df_zenit['Zenit_is_win'] = np.where(df_zenit['Home'] == 'Zenit', df_zenit['target'] == 0, df_zenit['target'] == 2)
plt.figure(figsize=(8, 6))
sns.histplot(data=df_zenit, y='Referee', hue='Zenit_is_win', multiple='dodge', shrink=0.8)
plt.xlabel('Referees')
plt.ylabel('Count')
plt.title('Зависимость побед Зенита от судей')
plt.show()
