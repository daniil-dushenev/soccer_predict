# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from catboost import Pool, CatBoostClassifier, cv

# %% [markdown]
# Преобразовали данные

# %%
data = pd.DataFrame()
def create_data(data, seasons=5):
    for i in range(seasons):
        df = pd.read_csv(f'{23-i-1}-{23-i}.csv', sep=';')
        df = df.iloc[:-4]
        df = df[['Wk', 'Day', 'Date', 'Time', 'Home', 'Score', 'Away', 'Referee']]
        df['Wk'] = df['Wk'].astype(int)
        df[['Home_score', 'Away_score']] = df['Score'].str.split('–', expand=True)
        df[['Home_score', 'Away_score']] = df[['Home_score', 'Away_score']].astype(int) 
        df['Month'] = df['Date'].apply(lambda x: x[3:5])
        df['Hours'] = df['Time'].apply(lambda x: x[:2]).astype(int)
        df = df.drop(['Score', 'Date', 'Time'], axis=1)
        df['target'] = np.where(df['Home_score'] > df['Away_score'], 0, 
                                np.where(df['Home_score'] < df['Away_score'], 2, 1))
        # 0 - победа хозяев, 1 - ничья, 2 - победа гостей
        df = df.drop(['Home_score', 'Away_score'], axis=1)
        total_df = pd.read_csv(f'{23-i-2}-{23-i-1}_table.csv', sep=';')
        total_df = dict(zip(total_df['Squad'], total_df['Rk']))
        df['Total_last_year_Home'] = df['Home'].apply(lambda x: total_df[x] if x in total_df else None)
        df['Total_last_year_Away'] = df['Away'].apply(lambda x: total_df[x] if x in total_df else None)
        data = pd.concat([data, df], axis=0)
        data = data.dropna()
    return data
df = create_data(df)

# %%
cat_features = ['Day', 'Home', 'Away', 'Referee', 'Month']
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis=1),
                                                    df['target'], test_size=0.2)

# %%
train = Pool(data=X_train,
             label=y_train,
             cat_features=cat_features)
test = Pool(data=X_test,
             label=y_test,
             cat_features=cat_features)

# %%
iter = 500
params = {
    "iterations":iter,
    "depth": 5,
    "custom_loss": "Accuracy",
    "learning_rate": 0.1,
    "loss_function": "MultiClass",
    "verbose": False
}
scores = cv(train,
            params,
           fold_count=5)
scores
# Out:
# Training on fold [0/5]
#
# bestTest = 0.9819500693
# bestIteration = 150
#
# Training on fold [1/5]
#
# bestTest = 1.049074943
# bestIteration = 49
#
# Training on fold [2/5]
#
# bestTest = 1.068622299
# bestIteration = 18
#
# Training on fold [3/5]
#
# bestTest = 1.017683001
# bestIteration = 58
#
# Training on fold [4/5]
#
# bestTest = 1.041306553
# bestIteration = 33
#      iterations  test-MultiClass-mean  test-MultiClass-std  \
# 0             0              1.091172             0.001591
# 1             1              1.087493             0.001774
# 2             2              1.083879             0.002711
# 3             3              1.080746             0.004863
# 4             4              1.076534             0.004659
# ..          ...                   ...                  ...
# 495         495              1.144532             0.058924
# 496         496              1.144460             0.059213
# 497         497              1.144646             0.059820
# 498         498              1.145213             0.059374
# 499         499              1.145760             0.059221
#
#      train-MultiClass-mean  train-MultiClass-std  test-Accuracy-mean  \
# 0                 1.086396              0.001394            0.428099
# 1                 1.079383              0.002844            0.448634
# 2                 1.069990              0.005775            0.451543
# 3                 1.062800              0.006796            0.464757
# 4                 1.055246              0.006380            0.469126
# ..                     ...                   ...                 ...
# 495               0.269103              0.009186            0.455881
# 496               0.268262              0.009356            0.455881
# 497               0.267830              0.009370            0.454422
# 498               0.267201              0.009287            0.454411
# 499               0.266731              0.009245            0.454411
#
#      test-Accuracy-std  train-Accuracy-mean  train-Accuracy-std
# 0             0.044674             0.493388            0.014891
# 1             0.034407             0.504765            0.015930
# 2             0.029571             0.512457            0.030074
# 3             0.015982             0.516493            0.013137
# 4             0.021701             0.517968            0.019005
# ..                 ...                  ...                 ...
# 495           0.057021             0.999633            0.000821
# 496           0.058860             0.999633            0.000821
# 497           0.059278             0.999633            0.000821
# 498           0.062635             0.999633            0.000821
# 499           0.062635             0.999633            0.000821
#
# [500 rows x 9 columns]

# %%
plt.figure(figsize=(15, 8))
plt.plot(np.arange(iter), scores['test-Accuracy-mean'].values, label='test scores')
plt.plot(np.arange(iter), scores['train-Accuracy-mean'].values, label='train scores')
plt.legend()
plt.grid(True)
plt.show()

# %%
cb = CatBoostClassifier(iterations=100, depth=5, custom_loss="Accuracy",
                        learning_rate=0.1, loss_function="MultiClass",
                        verbose=False)
cb.fit(train)
y_pred = cb.predict(test)
print("Accuracy: ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.47953216374269003

# %%
df = pd.read_csv(f'{23}-{24}.csv', sep=';')
df = df.iloc[:-4]
df = df[['Wk', 'Day', 'Date', 'Time', 'Home', 'Score', 'Away', 'Referee']]
df_score = df
df['Wk'] = df['Wk'].astype(int)
df[['Home_score', 'Away_score']] = df['Score'].str.split('–', expand=True)
df[['Home_score', 'Away_score']] = df[['Home_score', 'Away_score']].astype(int) 
df['Month'] = df['Date'].apply(lambda x: x[3:5])
df['Hours'] = df['Time'].apply(lambda x: x[:2]).astype(int)

df = df.drop(['Score', 'Date', 'Time'], axis=1)
df = df.drop(['Home_score', 'Away_score'], axis=1)
total_df = pd.read_csv(f'{22}-{23}_table.csv', sep=';')
total_df = dict(zip(total_df['Squad'], total_df['Rk']))
df['Total_last_year_Home'] = df['Home'].apply(lambda x: total_df[x] if x in total_df else None)
df['Total_last_year_Away'] = df['Away'].apply(lambda x: total_df[x] if x in total_df else None)
df = df.dropna()
df
# Out:
#     Wk  Day             Home             Away               Referee Month  \
# 0    1  Fri      Dynamo Mosc        Krasnodar       Kirill Levnikov    07
# 1    1  Sat             Ural      CSKA Moscow        Aleksey Amelin    07
# 2    1  Sat  Nizhny Novgorod            Zenit         Sergey Ivanov    07
# 4    1  Sat    Akhmat Grozny           Samara        Sergey Karasev    07
# 5    1  Sun   Spartak Moscow         Orenburg      Artem Chistyakov    07
# 6    1  Sun           Rostov   Fakel Voronezh     Pavel Shadykhanov    07
# 8    2  Sat           Samara      Dynamo Mosc        Artem Lyubimov    07
# 9    2  Sat             Ural  Nizhny Novgorod      Artem Chistyakov    07
# 10   2  Sat           Rostov            Zenit       Evgeny Kukulyak    07
# 12   2  Sun   Fakel Voronezh      Loko Moscow     Vasiliy Kazartsev    07
# 13   2  Sun    Akhmat Grozny      CSKA Moscow  Vladislav Bezborodov    07
# 14   2  Sun        Krasnodar            Sochi     Vladimir Moskalev    07
# 16   3  Fri        Krasnodar  Nizhny Novgorod        Artem Lyubimov    08
# 17   3  Sat           Samara           Rostov        Sergey Karasev    08
# 19   3  Sat         Orenburg             Ural        Rafael Shafeev    08
# 20   3  Sat      CSKA Moscow      Loko Moscow       Kirill Levnikov    08
#
#     Hours  Total_last_year_Home  Total_last_year_Away
# 0      19                   9.0                   6.0
# 1      15                  11.0                   2.0
# 2      15                  13.0                   1.0
# 4      20                   5.0                  12.0
# 5      17                   3.0                   7.0
# 6      20                   4.0                  14.0
# 8      16                  12.0                   9.0
# 9      19                  11.0                  13.0
# 10     20                   4.0                   1.0
# 12     17                  14.0                   8.0
# 13     20                   5.0                   2.0
# 14     20                   6.0                  10.0
# 16     20                   6.0                  13.0
# 17     16                  12.0                   4.0
# 19     19                   7.0                  11.0
# 20     20                   2.0                   8.0

# %%
for i in range(len(df)):
    match = df.iloc[i]
    result = {0: 'П1', 1: 'Н', 2: 'П2'}
    print(f"{match['Home']} - {match['Away']}", result[cb.predict(match)[0]], df_score.\
                         loc[(match['Home']==df_score['Home']) & (match['Away']==df_score['Away'])]['Score'].iloc[0],
                         cb.predict_proba(match))
# Out:
# Dynamo Mosc - Krasnodar П2 1–3 [0.24115659 0.37072326 0.38812014]
# Ural - CSKA Moscow Н 2–1 [0.18905151 0.4370059  0.3739426 ]
# Nizhny Novgorod - Zenit П2 0–2 [0.10992234 0.42696728 0.46311038]
# Akhmat Grozny - Samara П1 1–2 [0.63639556 0.15418852 0.20941592]
# Spartak Moscow - Orenburg П1 3–2 [0.54296517 0.23020716 0.22682766]
# Rostov - Fakel Voronezh П1 2–1 [0.69105274 0.16144182 0.14750544]
# Samara - Dynamo Mosc Н 3–3 [0.11363782 0.47779301 0.40856917]
# Ural - Nizhny Novgorod П1 0–0 [0.46175883 0.33946931 0.19877187]
# Rostov - Zenit Н 1–1 [0.22880763 0.41738876 0.35380361]
# Fakel Voronezh - Loko Moscow П2 1–4 [0.14926974 0.32577596 0.5249543 ]
# Akhmat Grozny - CSKA Moscow П2 2–3 [0.3476731  0.29047523 0.36185167]
# Krasnodar - Sochi П1 2–0 [0.43658925 0.26271138 0.30069937]
# Krasnodar - Nizhny Novgorod П1 1–0 [0.64386056 0.20755161 0.14858783]
# Samara - Rostov П2 5–1 [0.11919001 0.38272693 0.49808306]
# Orenburg - Ural Н 0–2 [0.28101521 0.45196775 0.26701704]
# CSKA Moscow - Loko Moscow П1 4–1 [0.50482008 0.27261726 0.22256266]

# %%
cb.get_feature_importance(train)
# Out:
# array([ 9.06686614,  8.22951573, 19.4562345 , 20.04851772,  7.59402712,
#         7.54786372,  3.90851137, 14.20137518,  9.94708851])

# %%
X_train.columns
# Out:
# Index(['Wk', 'Day', 'Home', 'Away', 'Referee', 'Month', 'Hours',
#        'Total_last_year_Home', 'Total_last_year_Away'],
#       dtype='object')
